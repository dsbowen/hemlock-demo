# %% [markdown]
# # Big 5 extension
#
# This extension allows you to add one of several big 5 personality inventories to your survey in 1 line of code.
#
# Check out <a href="https://dsbowen.github.io/hemlock-big5" target="_blank">the docs</a> for more details!

# %%
from hemlock import push_app_context

app = push_app_context()

# %%
from hemlock_big5 import big5

# ten-item personality inventory
# NOTE: if you're playing with this notebook in Binder, the javascript that makes this page beautiful won't work
# download the preview.html file generated by this cell to see what the page would look like in a survey
big5(version='TIPI', page=True).preview()
