# %% [markdown]
# # Berlin numeracy test extension
#
# This extension allows you to add an adaptive Berlin numeracy test to your survey in 1 line of code.
#
# Because it is adaptive, `preview` only shows you the first page of the test. Subsequent pages of the test are added adaptively depending on the participant's performance.
#
# Check out <a href="https://dsbowen.github.io/hemlock-berlin/" target="_blank">the docs</a> for more details!

# %%
from hemlock import push_app_context

app = push_app_context()

# %%
from hemlock_berlin import berlin

berlin().preview(filename='berlin')
